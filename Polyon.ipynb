# %% [markdown]
# ## Import library

# %%
import plotly.express as px
import pandas as pd
# import geopandas as gpd

# %% [markdown]
# ## To plot the area covered by each station

# %%
df_all = pd.DataFrame({'Location':['Batu Kawa Bridge','Ulu Maong','Maong Tengah Kiri','Kuching Saberkas','Satok Bridge'],
                       'dummy':[2,4,6,8,10]})

# %%
geojson_all = {
    'type': 'FeatureCollection',
    'features': [{'type': 'Feature',
                  'properties': {'Name': 'Batu Kawa Bridge'},
                  'geometry': {'type': 'Polygon','coordinates': [[[110.2268,1.4899],
                                                                  [110.2444, 1.4752],
                                                                  [110.3052, 1.4879],
                                                                  [110.3063, 1.4932],
                                                                  [110.3048, 1.4966],
                                                                  [110.2815, 1.5490],
                                                                  [110.2372, 1.5199],
                                                                  [110.2252, 1.4899]]]},
                  'id': 'Batu Kawa Bridge'},
                 {'type': 'Feature',
                  'properties': {'Name': 'Ulu Maong'},
                  'geometry': {'type': 'Polygon','coordinates': [[[110.3048,1.4966],
                                                                  [110.3063, 1.4932],
                                                                  [110.3057, 1.4902],
                                                                  [110.3667, 1.5140],
                                                                  [110.3309, 1.5279]]]},
                  'id': 'Ulu Maong'}, 
                 {'type': 'Feature',
                  'properties': {'Name': 'Maong Tengah Kiri'},
                  'geometry': {'type': 'Polygon','coordinates': [[[110.3048,1.4966],
                                                                  [110.3309, 1.5279],
                                                                  [110.3311, 1.5293],
                                                                  [110.3263, 1.5459],
                                                                  [110.3256, 1.5460],
                                                                  [110.2792, 1.5542],
                                                                  [110.2815, 1.5490]]]},
                  'id': 'Maong Tengah Kiri'},
                 {'type': 'Feature',
                  'properties': {'Name': 'Kuching Saberkas'},
                  'geometry': {'type': 'Polygon','coordinates': [[[110.3311,1.5293],
                                                                  [110.3310, 1.5282],
                                                                  [110.3500, 1.5407],
                                                                  [110.3397, 1.5539],
                                                                  [110.3256, 1.5460],
                                                                  [110.3263, 1.5459]]]},
                  'id': 'Kuching Saberkas'},
                 {'type': 'Feature',
                  'properties': {'Name': 'Satok Bridge'},
                  'geometry': {'type': 'Polygon','coordinates': [[[110.2792,1.5542],
                                                                  [110.3256, 1.5460],
                                                                  [110.3397, 1.5539],
                                                                  [110.3447, 1.5774],
                                                                  [110.3327, 1.5840],
                                                                  [110.2685, 1.5781]]]},
                  'id': 'Satok Bridge'}
             
             ]
              }

# %%
fig = px.choropleth_mapbox(df_all, geojson=geojson_all, locations='Location', color='dummy',
                           color_continuous_scale="sunset",
                           range_color=(0, 12),
                           mapbox_style="carto-positron",
                            zoom=10, center = {"lat": 1.4752, "lon": 110.2444},
                           opacity=0.5,
                           labels={'dummy':'Hourly Rainfall (mm)'}
                          )

# fig.add_trace(px.scatter_mapbox(df_location,lat='latitude',lon='longitude',mapbox_style="carto-positron"))

fig.update_layout(
    width=800,  # Set the width of the plot
    height=400,
    # showlegend=False,
    title="Area Covered in Kuching"
)

fig.update_layout(
    font=dict(
        family='Helvetica',  # Set the desired font style, e.g., 'Arial', 'Times New Roman', etc.
        size=12,         # Adjust the font size as needed
    )
)
fig.show()
fig.write_html('/Users/kang/Documents/Hackathon_2023/Boundary/all.html')

# %% [markdown]
# ## Individual Region

# %%
geojson_Batu_Kawa_Bridge = {'type': 'FeatureCollection',
 'features': [{'type': 'Feature',
   'properties': {'Name': 'Batu Kawa Bridge'},
   'geometry': {'type': 'Polygon',
    'coordinates': [[[110.2268,1.4899],
      [110.2444, 1.4752],
      [110.3052, 1.4879],
      [110.3063, 1.4932],
      [110.3048, 1.4966],
      [110.2815, 1.5490],
      [110.2372, 1.5199],
      [110.2252, 1.4899]]]},
   'id': 'Batu Kawa Bridge'}]}

# %%
geojson_Ulu_Maong = {'type': 'FeatureCollection',
 'features': [{'type': 'Feature',
   'properties': {'Name': 'Ulu Maong'},
   'geometry': {'type': 'Polygon',
    'coordinates': [[[110.3048,1.4966],
      [110.3063, 1.4932],
      [110.3057, 1.4902],
      [110.3667, 1.5140],
      [110.3309, 1.5279]]]},
   'id': 'Ulu Maong'}]}

# %%
geojson_Maong_Tengah_Kiri = {'type': 'FeatureCollection',
 'features': [{'type': 'Feature',
   'properties': {'Name': 'Maong Tengah Kiri'},
   'geometry': {'type': 'Polygon',
    'coordinates': [[[110.3048,1.4966],
      [110.3309, 1.5279],
      [110.3311, 1.5293],
      [110.3263, 1.5459],
      [110.3256, 1.5460],
      [110.2792, 1.5542],
      [110.2815, 1.5490]]]},
   'id': 'Maong Tengah Kiri'}]}

# %%
geojson_Kuching_Saberkas = {'type': 'FeatureCollection',
 'features': [{'type': 'Feature',
   'properties': {'Name': 'Kuching Saberkas'},
   'geometry': {'type': 'Polygon',
    'coordinates': [[[110.3311,1.5293],
      [110.3310, 1.5282],
      [110.3500, 1.5407],
      [110.3397, 1.5539],
      [110.3256, 1.5460],
      [110.3263, 1.5459]]]},
   'id': 'Kuching Saberkas'}]}

# %%
geojson_Satok_Bridge = {'type': 'FeatureCollection',
 'features': [{'type': 'Feature',
   'properties': {'Name': 'Satok Bridge'},
   'geometry': {'type': 'Polygon',
    'coordinates': [[[110.2792,1.5542],
      [110.3256, 1.5460],
      [110.3397, 1.5539],
      [110.3447, 1.5774],
      [110.3327, 1.5840],
      [110.2685, 1.5781]]]},
   'id': 'Satok Bridge'}]}

# %%
df_Batu_Kawa_Bridge = pd.DataFrame({'Location':['Batu Kawa Bridge'],'dummy':[0.5]})
df_Ulu_Maong = pd.DataFrame({'Location':['Ulu Maong'],'dummy':[0.5]})
df_Maong_Tengah_Kiri = pd.DataFrame({'Location':['Maong Tengah Kiri'],'dummy':[0.5]})
df_Kuching_Saberkas = pd.DataFrame({'Location':['Kuching Saberkas'],'dummy':[0.5]})
df_Satok_Bridge = pd.DataFrame({'Location':['Satok Bridge'],'dummy':[0.5]})

df_location = pd.DataFrame({'latitude':[1.50922],'longitude':[110.26669]})

# %%
import plotly.express as px

fig = px.choropleth_mapbox(df_Ulu_Maong, geojson=geojson_Ulu_Maong, locations='Location',
                           color_discrete_map={"1":'red'},
                           range_color=(0, 12),
                           mapbox_style="carto-positron",
                           zoom=10, center = {"lat": 1.4752, "lon": 110.2444},
                           opacity=0.5,
                           
                          )
# fig.add_trace(px.scatter_mapbox(df_location,lon='longitude',lat='latitude'))


fig.update_layout(
    width=800,  # Set the width of the plot
    height=400,
    showlegend=False,
    title="Area Covered by Ulu Maong"
)

fig.show()
fig.write_html('/Users/kang/Desktop/Hackathon_2023/Boundary/Ulu Maong.html')
